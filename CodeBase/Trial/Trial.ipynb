# %%
# !pip install -q --upgrade --force-reinstall \
numpy==1.26.4 \
scipy==1.11.4 \
scikit-learn==1.4.2 \
pandas==2.1.4 \
matplotlib==3.8.4 \
seaborn==0.13.2 \
shap==0.44.1 \
lime==0.2.0.1 \
xgboost==2.0.3
# Out:
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [499 lines of output]
#       + meson setup /tmp/pip-install-la0vqd45/scipy_8c733276598642e399a5cb3c9bef0040 /tmp/pip-install-la0vqd45/scipy_8c733276598642e399a5cb3c9bef0040/.mesonpy-w4_v_ku_ -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/tmp/pip-install-la0vqd45/scipy_8c733276598642e399a5cb3c9bef0040/.mesonpy-w4_v_ku_/meson-python-native-file.ini
#       The Meson build system
#       Version: 1.10.1
#       Source dir: /tmp/pip-install-la0vqd45/scipy_8c733276598642e399a5cb3c9bef0040
#       Build dir: /tmp/pip-install-la0vqd45/scipy_8c733276598642e399a5cb3c9bef0040/.mesonpy-w4_v_ku_
#       Build type: native build
#       Project name: SciPy
#       Project version: 1.11.4
#       C compiler for the host machine: cc (gcc 15.2.0 "cc (Debian 15.2.0-12) 15.2.0")
#       C linker for the host machine: cc ld.bfd 2.45.50.20251209
#       C++ compiler for the host machine: c++ (gcc 15.2.0 "c++ (Debian 15.2.0-12) 15.2.0")
#       C++ linker for the host machine: c++ ld.bfd 2.45.50.20251209
#       Cython compiler for the host machine: cython (cython 0.29.37)
#       Host machine cpu family: x86_64
#       Host machine cpu: x86_64
#       Program python found: YES (/media/spyder/Secondary-Disk/Github/Student-Performance-Prediction-with-Explainable-AI/CodeBase/Trial/.spenv/bin/python3)
#       Found pkg-config: YES (/usr/bin/pkg-config) 1.8.1
#       Run-time dependency python found: YES 3.13
#       Program cython found: YES (/tmp/pip-build-env-z4tszrkn/overlay/bin/cython)
#       Compiler for C supports arguments -Wno-unused-but-set-variable: YES
#       Compiler for C supports arguments -Wno-unused-function: YES
#       Compiler for C supports arguments -Wno-conversion: YES
#       Compiler for C supports arguments -Wno-misleading-indentation: YES
#       Library m found: YES
#       Fortran compiler for the host machine: gfortran (gcc 15.2.0 "GNU Fortran (Debian 15.2.0-12) 15.2.0")
#       Fortran linker for the host machine: gfortran ld.bfd 2.45.50.20251209
#       Compiler for Fortran supports arguments -Wno-conversion: YES
#       Checking if "-Wl,--version-script" links: YES
#       Program pythran found: YES (/tmp/pip-build-env-z4tszrkn/overlay/bin/pythran)
#       Found pkg-config: YES (/usr/bin/pkg-config) 1.8.1
#       Found CMake: /usr/bin/cmake (3.31.6)
#       Run-time dependency xsimd found: NO (tried pkgconfig and cmake)
#       Run-time dependency threads found: YES
#       Library npymath found: YES
#       Library npyrandom found: YES
#       Run-time dependency pybind11 found: YES 3.0.1
#       Run-time dependency openblas found: YES 0.3.29
#       Dependency openblas found: YES 0.3.29 (cached)
#       Compiler for C supports arguments -Wno-maybe-uninitialized: YES
#       Compiler for C supports arguments -Wno-discarded-qualifiers: YES
#       Compiler for C supports arguments -Wno-empty-body: YES
#       Compiler for C supports arguments -Wno-implicit-function-declaration: YES
#       Compiler for C supports arguments -Wno-parentheses: YES
#       Compiler for C supports arguments -Wno-switch: YES
#       Compiler for C supports arguments -Wno-unused-label: YES
#       Compiler for C supports arguments -Wno-unused-variable: YES
#       Compiler for C supports arguments -Wno-incompatible-pointer-types: YES
#       Compiler for C++ supports arguments -Wno-cpp: YES
#       Compiler for C++ supports arguments -Wno-deprecated-declarations: YES
#       Compiler for C++ supports arguments -Wno-class-memaccess: YES
#       Compiler for C++ supports arguments -Wno-format-truncation: YES
#       Compiler for C++ supports arguments -Wno-non-virtual-dtor: YES
#       Compiler for C++ supports arguments -Wno-sign-compare: YES
#       Compiler for C++ supports arguments -Wno-switch: YES
#       Compiler for C++ supports arguments -Wno-terminate: YES
#       Compiler for C++ supports arguments -Wno-unused-but-set-variable: YES
#       Compiler for C++ supports arguments -Wno-unused-function: YES
#       Compiler for C++ supports arguments -Wno-unused-local-typedefs: YES
#       Compiler for C++ supports arguments -Wno-unused-variable: YES
#       Compiler for C++ supports arguments -Wno-int-in-bool-context: YES
#       Compiler for Fortran supports arguments -Wno-argument-mismatch: YES
#       Compiler for Fortran supports arguments -Wno-conversion: YES (cached)
#       Compiler for Fortran supports arguments -Wno-intrinsic-shadow: YES
#       Compiler for Fortran supports arguments -Wno-maybe-uninitialized: YES
#       Compiler for Fortran supports arguments -Wno-surprising: YES
#       Compiler for Fortran supports arguments -Wno-uninitialized: YES
#       Compiler for Fortran supports arguments -Wno-unused-dummy-argument: YES
#       Compiler for Fortran supports arguments -Wno-unused-label: YES
#       Compiler for Fortran supports arguments -Wno-unused-variable: YES
#       Compiler for Fortran supports arguments -Wno-tabs: YES
#       Compiler for Fortran supports arguments -Wno-argument-mismatch: YES (cached)
#       Compiler for Fortran supports arguments -Wno-conversion: YES (cached)
#       Compiler for Fortran supports arguments -Wno-maybe-uninitialized: YES (cached)
#       Compiler for Fortran supports arguments -Wno-unused-dummy-argument: YES (cached)
#       Compiler for Fortran supports arguments -Wno-unused-label: YES (cached)
#       Compiler for Fortran supports arguments -Wno-unused-variable: YES (cached)
#       Compiler for Fortran supports arguments -Wno-tabs: YES (cached)
#       Checking if "Check atomic builtins without -latomic" links: YES
#       Configuring __config__.py using configuration
#       DEPRECATION: Variable substitution with boolean value 'CROSS_COMPILED' is deprecated.
#       DEPRECATION: Variable substitution with boolean value 'BLAS_FOUND' is deprecated.
#       DEPRECATION: Variable substitution with boolean value 'LAPACK_FOUND' is deprecated.
#       Run-time dependency python found: YES 3.13
#       Checking for function "open_memstream" : NO
#       Configuring messagestream_config.h using configuration
#       Compiler for Fortran supports arguments -w: YES
#       Checking for size of "void*" : 8
#       Compiler for C supports arguments -Wno-unused-variable: YES (cached)
#       Compiler for C supports arguments -Wno-parentheses: YES (cached)
#       Compiler for C supports arguments -Wno-unused-label: YES (cached)
#       Compiler for C supports arguments -Wno-implicit-function-declaration: YES (cached)
#       Compiler for C supports arguments -Wno-switch: YES (cached)
#       Compiler for Fortran supports arguments -w: YES (cached)
#       Checking for size of "void*" : 8 (cached)
#       Build targets in project: 257
#
#       SciPy 1.11.4
#
#         User defined options
#           Native files: /tmp/pip-install-la0vqd45/scipy_8c733276598642e399a5cb3c9bef0040/.mesonpy-w4_v_ku_/meson-python-native-file.ini
#           b_ndebug    : if-release
#           b_vscrt     : md
#           buildtype   : release
#
#       Found ninja-1.13.2 at /usr/bin/ninja
#       + /usr/bin/ninja
#       [1/1661] Copying file scipy/stats/unuran.pxd
#       [2/1661] Copying file scipy/stats/_stats.pxd
#       [3/1661] Generating scipy/linalg/cython_linalg with a custom command
#       [4/1661] Copying file scipy/stats/__init__.py
#       [5/1661] Copying file scipy/stats/_biasedurn.pxd
#       [6/1661] Generating scipy/special/cython_special with a custom command
#       [7/1661] Scanning target lib__spropack for modules
#       [8/1661] Scanning target cdflib for modules
#       [9/1661] Scanning target fwrappers for modules
#       [10/1661] Scanning target specfun for modules
#       [11/1661] Generating scipy/sparse/linalg/_isolve/methods_f_1 with a custom command
#       [12/1661] Scanning target mach for modules
#       [13/1661] Generating scipy/sparse/linalg/_isolve/methods_f_0 with a custom command
#       [14/1661] Scanning target lib__dpropack for modules
#       [15/1661] Generating scipy/sparse/linalg/_isolve/methods_f_3 with a custom command
#       [16/1661] Scanning target amos for modules
#       [17/1661] Generating scipy/sparse/linalg/_isolve/methods_f_2 with a custom command
#       [18/1661] Generating scipy/sparse/linalg/_isolve/methods_f_5 with a custom command
#       [19/1661] Scanning target lib__zpropack for modules
#       [20/1661] Generating scipy/sparse/linalg/_isolve/methods_f_4 with a custom command
#       [21/1661] Generating scipy/sparse/linalg/_propack/propack_module_spropack with a custom command
#       [22/1661] Generating scipy/sparse/linalg/_isolve/Util_f_0 with a custom command
#       [23/1661] Scanning target lib__cpropack for modules
#       [24/1661] Generating scipy/stats/_stats_gen_pyx with a custom command
#       [25/1661] Generating scipy/sparse/linalg/_propack/propack_module_zpropack with a custom command
#       [26/1661] Scanning target arpack_lib for modules
#       [27/1661] Generating scipy/sparse/linalg/_propack/propack_module_cpropack with a custom command
#       [28/1661] Generating scipy/sparse/linalg/_propack/propack_module_dpropack with a custom command
#       [29/1661] Scanning target statlib_lib for modules
#       [30/1661] Scanning target dop_lib for modules
#       [31/1661] Scanning target lsoda_lib for modules
#       [32/1661] Generating scipy/integrate/lsoda_module with a custom command
#       [33/1661] Scanning target mach_lib for modules
#       [34/1661] Scanning target quadpack_lib for modules
#       [35/1661] Generating scipy/integrate/_test_odeint_banded_module with a custom command
#       [36/1661] Generating scipy/stats/mvn_module with a custom command
#       [37/1661] Generating scipy/integrate/vode_module with a custom command
#       [38/1661] Generating scipy/sparse/linalg/_eigen/arpack/arpack_module with a custom command
#       [39/1661] Scanning target vode_lib for modules
#       [40/1661] Copying file scipy/__init__.py
#       [41/1661] Copying file scipy/optimize/cython_optimize/__init__.py
#       [42/1661] Scanning target fitpack_lib for modules
#       [43/1661] Generating scipy/stats/statlib_module with a custom command
#       [44/1661] Copying file scipy/special.pxd
#       [45/1661] Generating scipy/integrate/_dop_module with a custom command
#       [46/1661] Copying file scipy/_lib/messagestream.pxd
#       [47/1661] Copying file scipy/_lib/ccallback.pxd
#       [48/1661] Copying file scipy/optimize.pxd
#       [49/1661] Copying file scipy/_lib/_ccallback_c.pxd
#       [50/1661] Scanning target minpack for modules
#       [51/1661] Copying file scipy/linalg.pxd
#       [52/1661] Copying file scipy/_lib/__init__.py
#       [53/1661] Copying file scipy/special/_boxcox.pxd
#       [54/1661] Copying file scipy/special/_cephes.pxd
#       [55/1661] Scanning target odrpack for modules
#       [56/1661] Copying file scipy/special/_agm.pxd
#       [57/1661] Copying file scipy/special/__init__.py
#       [58/1661] Copying file scipy/special/_convex_analysis.pxd
#       [59/1661] Copying file scipy/special/_ellipk.pxd
#       [60/1661] Copying file scipy/special/_cunity.pxd
#       [61/1661] Copying file scipy/special/_ellip_harm.pxd
#       [62/1661] Copying file scipy/special/_exprel.pxd
#       [63/1661] Copying file scipy/special/_factorial.pxd
#       [64/1661] Copying file scipy/special/_digamma.pxd
#       [65/1661] Copying file scipy/special/_complexstuff.pxd
#       [66/1661] Copying file scipy/special/_ellip_harm_2.pxd
#       [67/1661] Copying file scipy/special/_evalpoly.pxd
#       [68/1661] Generating scipy/optimize/lbfgsb_module with a custom command
#       [69/1661] Copying file scipy/special/_hyp2f1.pxd
#       [70/1661] Copying file scipy/special/_hyp0f1.pxd
#       [71/1661] Copying file scipy/special/_lambertw.pxd
#       [72/1661] Copying file scipy/special/_spence.pxd
#       [73/1661] Copying file scipy/special/_legacy.pxd
#       [74/1661] Copying file scipy/special/_loggamma.pxd
#       [75/1661] Copying file scipy/special/_hypergeometric.pxd
#       [76/1661] Copying file scipy/special/_spherical_bessel.pxd
#       [77/1661] Copying file scipy/special/_wright_bessel.pxd
#       [78/1661] Copying file scipy/special/_ndtri_exp.pxd
#       [79/1661] Copying file scipy/special/_sici.pxd
#       [80/1661] Copying file scipy/special/_ufuncs_extra_code.pxi
#       [81/1661] Copying file scipy/special/orthogonal_eval.pxd
#       [82/1661] Copying file scipy/special/_cython_special.pxi
#       [83/1661] Copying file scipy/special/sf_error.pxd
#       [84/1661] Copying file scipy/special/_cython_special_custom.pxi
#       [85/1661] Copying file scipy/special/_trig.pxd
#       [86/1661] Generating scipy/special/_dummy_cython_special.pxd with a custom command
#       [87/1661] Copying file scipy/special/_xlogy.pxd
#       [88/1661] Copying file scipy/special/sph_harm.pxd
#       [89/1661] Generating scipy/linalg/_dummy_cython_blas.pxd with a custom command
#       [90/1661] Generating dynamic dependency information for target cdflib
#       [91/1661] Generating dynamic dependency information for target amos
#       [92/1661] Copying file scipy/special/_ufuncs_extra_code_common.pxi
#       [93/1661] Generating dynamic dependency information for target specfun
#       [94/1661] Generating dynamic dependency information for target mach
#       [95/1661] Copying file scipy/linalg/__init__.py
#       [96/1661] Copying file scipy/linalg/_cythonized_array_utils.pxd
#       [97/1661] Generating dynamic dependency information for target fwrappers
#       [98/1661] Generating scipy/sparse/_csparsetools_pyx with a custom command
#       [99/1661] Generating scipy/linalg/_matfuncs_expm with a custom command
#       [100/1661] Generating scipy/linalg/_decomp_update with a custom command
#       [101/1661] Generating dynamic dependency information for target lib__dpropack
#       [102/1661] Generating dynamic dependency information for target lib__spropack
#       [103/1661] Generating dynamic dependency information for target lib__cpropack
#       [104/1661] Generating dynamic dependency information for target lib__zpropack
#       [105/1661] Generating dynamic dependency information for target arpack_lib
#       [106/1661] Scanning target _flinalg.cpython-313-x86_64-linux-gnu for modules
#       [107/1661] Generating scipy/stats/_dummy_stats_gen_pyx with a custom command
#       [108/1661] Scanning target _spropack.cpython-313-x86_64-linux-gnu for modules
#       [109/1661] Generating dynamic dependency information for target statlib_lib
#       [110/1661] Scanning target _cpropack.cpython-313-x86_64-linux-gnu for modules
#       [111/1661] Scanning target _zpropack.cpython-313-x86_64-linux-gnu for modules
#       [112/1661] Generating dynamic dependency information for target quadpack_lib
#       [113/1661] Scanning target _dpropack.cpython-313-x86_64-linux-gnu for modules
#       [114/1661] Copying file scipy/spatial/setlist.pxd
#       [115/1661] Generating dynamic dependency information for target mach_lib
#       [116/1661] Scanning target _statlib.cpython-313-x86_64-linux-gnu for modules
#       [117/1661] Scanning target _interpolative.cpython-313-x86_64-linux-gnu for modules
#       [118/1661] Copying file scipy/spatial/_qhull.pxd
#       [119/1661] Scanning target _arpack.cpython-313-x86_64-linux-gnu for modules
#       [120/1661] Generating dynamic dependency information for target lsoda_lib
#       [121/1661] Generating dynamic dependency information for target vode_lib
#       [122/1661] Scanning target _iterative.cpython-313-x86_64-linux-gnu for modules
#       [123/1661] Scanning target _mvn.cpython-313-x86_64-linux-gnu for modules
#       [124/1661] Generating dynamic dependency information for target dop_lib
#       [125/1661] Generating dynamic dependency information for target fitpack_lib
#       [126/1661] Generating dynamic dependency information for target minpack
#       [127/1661] Generating dynamic dependency information for target odrpack
#       [128/1661] Generating scipy/interpolate/dfitpack_module with a custom command
#       [129/1661] Copying file scipy/optimize/__init__.py
#       [130/1661] Scanning target _vode.cpython-313-x86_64-linux-gnu for modules
#       [131/1661] Copying file scipy/optimize/cython_optimize/_zeros.pxd
#       [132/1661] Copying file scipy/optimize/cython_optimize/c_zeros.pxd
#       [133/1661] Copying file scipy/optimize/cython_optimize.pxd
#       [134/1661] Scanning target _slsqp.cpython-313-x86_64-linux-gnu for modules
#       [135/1661] Scanning target _cobyla.cpython-313-x86_64-linux-gnu for modules
#       [136/1661] Scanning target _lbfgsb.cpython-313-x86_64-linux-gnu for modules
#       [137/1661] Generating scipy/optimize/cython_optimize/_zeros_pyx with a custom command
#       [138/1661] Scanning target _lsoda.cpython-313-x86_64-linux-gnu for modules
#       [139/1661] Scanning target _minpack2.cpython-313-x86_64-linux-gnu for modules
#       [140/1661] Scanning target _dop.cpython-313-x86_64-linux-gnu for modules
#       [141/1661] Scanning target _test_odeint_banded.cpython-313-x86_64-linux-gnu for modules
#       [142/1661] Scanning target dfitpack.cpython-313-x86_64-linux-gnu for modules
#       [143/1661] Scanning target __nnls.cpython-313-x86_64-linux-gnu for modules
#       [144/1661] Compiling C object scipy/special/libcephes.a.p/cephes_bdtr.c.o
#       [145/1661] Compiling C object scipy/special/libcephes.a.p/cephes_cbrt.c.o
#       [146/1661] Compiling C object scipy/special/libcephes.a.p/cephes_besselpoly.c.o
#       [147/1661] Compiling C object scipy/special/libcephes.a.p/cephes_beta.c.o
#       [148/1661] Compiling C object scipy/special/libcephes.a.p/cephes_btdtr.c.o
#       [149/1661] Compiling C object scipy/special/libcephes.a.p/cephes_airy.c.o
#       [150/1661] Compiling C object scipy/special/libcephes.a.p/cephes_const.c.o
#       [151/1661] Compiling C object scipy/special/libcephes.a.p/cephes_chdtr.c.o
#       [152/1661] Compiling C object scipy/special/libcephes.a.p/cephes_chbevl.c.o
#       [153/1661] Compiling C object scipy/special/libcephes.a.p/cephes_dawsn.c.o
#       [154/1661] Scanning target _test_fortran.cpython-313-x86_64-linux-gnu for modules
#       [155/1661] Generating 'scipy/_lib/_test_deprecation_call.cpython-313-x86_64-linux-gnu.so.p/_test_deprecation_call.c'
#       [156/1661] Generating 'scipy/_lib/_test_deprecation_def.cpython-313-x86_64-linux-gnu.so.p/_test_deprecation_def.c'
#       [157/1661] Compiling C object scipy/special/libcephes.a.p/cephes_ellik.c.o
#       [158/1661] Compiling C object scipy/special/libcephes.a.p/cephes_exp10.c.o
#       [159/1661] Compiling C object scipy/special/libcephes.a.p/cephes_ellpe.c.o
#       [160/1661] Compiling C object scipy/special/libcephes.a.p/cephes_ellpj.c.o
#       [161/1661] Compiling C object scipy/special/libcephes.a.p/cephes_ellpk.c.o
#       [162/1661] Compiling C object scipy/special/libcephes.a.p/cephes_erfinv.c.o
#       [163/1661] Compiling C object scipy/special/libcephes.a.p/cephes_ellie.c.o
#       [164/1661] Compiling C object scipy/special/libcephes.a.p/cephes_exp2.c.o
#       [165/1661] Compiling C object scipy/lib_fortranobject.a.p/abf7d3230e362c9ccb931bff21bc6ab4af7661e4_site-packages_numpy_f2py_src_fortranobject.c.o
#       [166/1661] Compiling C object scipy/special/libcephes.a.p/cephes_fdtr.c.o
#       [167/1661] Compiling C object scipy/special/libcephes.a.p/cephes_gdtr.c.o
#       [168/1661] Compiling C object scipy/special/libcephes.a.p/cephes_gammasgn.c.o
#       [169/1661] Generating 'scipy/_lib/messagestream.cpython-313-x86_64-linux-gnu.so.p/messagestream.c'
#       [170/1661] Compiling C object scipy/special/libcephes.a.p/cephes_hyperg.c.o
#       [171/1661] Compiling C object scipy/special/libcephes.a.p/cephes_expn.c.o
#       [172/1661] Compiling C object scipy/special/libcephes.a.p/cephes_i0.c.o
#       [173/1661] Compiling C object scipy/special/libcephes.a.p/cephes_gamma.c.o
#       [174/1661] Compiling C object scipy/special/libcephes.a.p/cephes_fresnl.c.o
#       [175/1661] Compiling C object scipy/special/libcephes.a.p/cephes_i1.c.o
#       [176/1661] Generating 'scipy/_lib/_ccallback_c.cpython-313-x86_64-linux-gnu.so.p/_ccallback_c.c'
#       [177/1661] Compiling C object scipy/special/libcephes.a.p/cephes_dd_real.c.o
#       [178/1661] Compiling C object scipy/special/libcephes.a.p/cephes_k1.c.o
#       [179/1661] Generating scipy/linalg/fblas_module with a custom command
#       [180/1661] Compiling C object scipy/special/libcephes.a.p/cephes_incbet.c.o
#       [181/1661] Compiling C object scipy/special/libcephes.a.p/cephes_incbi.c.o
#       [182/1661] Compiling C object scipy/special/libcephes.a.p/cephes_igam.c.o
#       [183/1661] Compiling C object scipy/special/libcephes.a.p/cephes_j1.c.o
#       [184/1661] Compiling C object scipy/special/libcephes.a.p/cephes_j0.c.o
#       [185/1661] Compiling C object scipy/special/libcephes.a.p/cephes_lanczos.c.o
#       [186/1661] Compiling C object scipy/special/libcephes.a.p/cephes_kn.c.o
#       [187/1661] Compiling C object scipy/special/libcephes.a.p/cephes_k0.c.o
#       [188/1661] Compiling C object scipy/special/libcephes.a.p/cephes_igami.c.o
#       [189/1661] Compiling C object scipy/special/libcephes.a.p/cephes_hyp2f1.c.o
#       [190/1661] Compiling C object scipy/special/libcephes.a.p/cephes_nbdtr.c.o
#       [191/1661] Compiling C object scipy/special/libcephes.a.p/cephes_pdtr.c.o
#       [192/1661] Compiling C object scipy/special/libcephes.a.p/cephes_ndtr.c.o
#       [193/1661] Compiling C object scipy/special/libcephes.a.p/cephes_ndtri.c.o
#       [194/1661] Compiling C object scipy/special/libcephes.a.p/cephes_psi.c.o
#       [195/1661] Compiling C object scipy/special/libcephes.a.p/cephes_rgamma.c.o
#       [196/1661] Compiling C object scipy/special/libcephes.a.p/cephes_poch.c.o
#       [197/1661] Compiling C object scipy/special/libcephes.a.p/cephes_round.c.o
#       [198/1661] Compiling C object scipy/special/libcephes.a.p/cephes_shichi.c.o
#       [199/1661] Compiling C object scipy/special/libcephes.a.p/cephes_jv.c.o
#       [200/1661] Compiling C object scipy/special/libcephes.a.p/cephes_owens_t.c.o
#       [201/1661] Scanning target _fblas.cpython-313-x86_64-linux-gnu for modules
#       [202/1661] Compiling C object scipy/special/libcephes.a.p/cephes_sinpi.c.o
#       [203/1661] Compiling C object scipy/special/libcephes.a.p/cephes_spence.c.o
#       [204/1661] Compiling C object scipy/special/libcephes.a.p/cephes_sindg.c.o
#       [205/1661] Compiling C object scipy/special/libcephes.a.p/cephes_tandg.c.o
#       [206/1661] Compiling C object scipy/special/libcephes.a.p/cephes_sici.c.o
#       [207/1661] Compiling C object scipy/special/libcephes.a.p/cephes_yn.c.o
#       [208/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_dgamln.f.o
#       [209/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zabs.f.o
#       [210/1661] Compiling C object scipy/special/libcephes.a.p/cephes_yv.c.o
#       [211/1661] Compiling C object scipy/special/libcephes.a.p/cephes_zeta.c.o
#       [212/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zacai.f.o
#       [213/1661] Compiling C object scipy/special/libcephes.a.p/cephes_unity.c.o
#       [214/1661] Compiling C object scipy/special/libcephes.a.p/cephes_stdtr.c.o
#       [215/1661] Compiling C object scipy/special/libcephes.a.p/cephes_scipy_iv.c.o
#       [216/1661] Compiling C object scipy/special/libcephes.a.p/cephes_tukey.c.o
#       [217/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zasyi.f.o
#       [218/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zairy.f.o
#       [219/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbesy.f.o
#       [220/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbesj.f.o
#       [221/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zacon.f.o
#       [222/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbesi.f.o
#       [223/1661] Compiling C object scipy/special/libcephes.a.p/cephes_zetac.c.o
#       [224/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbunk.f.o
#       [225/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zdiv.f.o
#       [226/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbesh.f.o
#       [227/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbesk.f.o
#       [228/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbinu.f.o
#       [229/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zexp.f.o
#       [230/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbuni.f.o
#       [231/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zmlt.f.o
#       [232/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zlog.f.o
#       [233/1661] Compiling C object scipy/special/libcephes.a.p/cephes_kolmogorov.c.o
#       [234/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbiry.f.o
#       [235/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zsqrt.f.o
#       [236/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zshch.f.o
#       [237/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zuchk.f.o
#       [238/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zs1s2.f.o
#       [239/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zrati.f.o
#       [240/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zkscl.f.o
#       [241/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zseri.f.o
#       [242/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zwrsk.f.o
#       [243/1661] Compiling C object scipy/special/libcephes.a.p/cephes_struve.c.o
#       [244/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_algdiv.f.o
#       [245/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_alngam.f.o
#       [246/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_alnrel.f.o
#       [247/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_bcorr.f.o
#       [248/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zmlri.f.o
#       [249/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zunik.f.o
#       [250/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zuni2.f.o
#       [251/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_apser.f.o
#       [252/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zuni1.f.o
#       [253/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zuoik.f.o
#       [254/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_betaln.f.o
#       [255/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zbknu.f.o
#       [256/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_bfrac.f.o
#       [257/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_bgrat.f.o
#       [258/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_bpser.f.o
#       [259/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_brcmp1.f.o
#       [260/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_brcomp.f.o
#       [261/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_bup.f.o
#       [262/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_bratio.f.o
#       [263/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfchn.f.o
#       [264/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zunk1.f.o
#       [265/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfbin.f.o
#       [266/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfnor.f.o
#       [267/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfgam.f.o
#       [268/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_basym.f.o
#       [269/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfchi.f.o
#       [270/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfbet.f.o
#       [271/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumbet.f.o
#       [272/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdffnc.f.o
#       [273/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdff.f.o
#       [274/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfpoi.f.o
#       [275/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdft.f.o
#       [276/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdftnc.f.o
#       [277/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumchi.f.o
#       [278/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumbin.f.o
#       [279/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumf.f.o
#       [280/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cdfnbn.f.o
#       [281/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumnbn.f.o
#       [282/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zunhj.f.o
#       [283/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumchn.f.o
#       [284/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumgam.f.o
#       [285/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_dinvnr.f.o
#       [286/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumt.f.o
#       [287/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_dt1.f.o
#       [288/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumpoi.f.o
#       [289/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_devlpl.f.o
#       [290/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumnor.f.o
#       [291/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_dinvr.f.o
#       [292/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_exparg.f.o
#       [293/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_erfc1.f.o
#       [294/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_esum.f.o
#       [295/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_fpser.f.o
#       [296/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_erf.f.o
#       [297/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_dzror.f.o
#       [298/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumfnc.f.o
#       [299/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_cumtnc.f.o
#       [300/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_gam1.f.o
#       [301/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_gamln.f.o
#       [302/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_gamln1.f.o
#       [303/1661] Compiling Fortran object scipy/special/libamos.a.p/amos_zunk2.f.o
#       [304/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_ipmpar.f.o
#       [305/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_rlog1.f.o
#       [306/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_rexp.f.o
#       [307/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_gsumln.f.o
#       [308/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_spmpar.f.o
#       [309/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_rcomp.f.o
#       [310/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_rlog.f.o
#       [311/1661] Compiling Fortran object scipy/special/libmach.a.p/mach_d1mach.f.o
#       [312/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_gamma_fort.f.o
#       [313/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_grat1.f.o
#       [314/1661] Compiling Fortran object scipy/special/libmach.a.p/mach_xerror.f.o
#       [315/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_stvaln.f.o
#       [316/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_psi_fort.f.o
#       [317/1661] Compiling Fortran object scipy/special/libmach.a.p/mach_i1mach.f.o
#       [318/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_gaminv.f.o
#       [319/1661] Compiling Fortran object scipy/special/libcdflib.a.p/cdflib_gratio.f.o
#       [320/1661] Generating dynamic dependency information for target _flinalg.cpython-313-x86_64-linux-gnu
#       [321/1661] Generating dynamic dependency information for target _fblas.cpython-313-x86_64-linux-gnu
#       [322/1661] Generating dynamic dependency information for target _interpolative.cpython-313-x86_64-linux-gnu
#       [323/1661] Generating 'scipy/special/_comb.cpython-313-x86_64-linux-gnu.so.p/_comb.c'
#       [324/1661] Compiling Fortran object scipy/linalg/libfwrappers.a.p/meson-generated_..__blas_subroutine_wrappers.f.o
#       [325/1661] Compiling Fortran object scipy/linalg/libfwrappers.a.p/..__build_utils_src_wrap_dummy_g77_abi.f.o
#       [326/1661] Generating scipy/linalg/flinalg_module with a custom command
#       [327/1661] Generating scipy/special/specfun_module with a custom command
#       [328/1661] Compiling Fortran object scipy/linalg/libfwrappers.a.p/meson-generated_..__lapack_subroutine_wrappers.f.o
#       [329/1661] Generating 'scipy/special/_ufuncs_cxx.cpython-313-x86_64-linux-gnu.so.p/_ufuncs_cxx.cpp'
#       [330/1661] Generating 'scipy/special/_ellip_harm_2.cpython-313-x86_64-linux-gnu.so.p/_ellip_harm_2.c'
#       [331/1661] Generating 'scipy/special/cython_special.cpython-313-x86_64-linux-gnu.so.p/cython_special.c'
#       FAILED: [code=1] scipy/special/cython_special.cpython-313-x86_64-linux-gnu.so.p/cython_special.c
#       /tmp/pip-build-env-z4tszrkn/overlay/bin/cython -3 --fast-fail --output-file scipy/special/cython_special.cpython-313-x86_64-linux-gnu.so.p/cython_special.c --include-dir . scipy/special/cython_special.pyx
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#
#       cdef inline number_t zpow(number_t x, double y) noexcept nogil:
#           cdef np.npy_cdouble r, z
#           # FIXME
#           if number_t is double_complex:
#               z.real = y
#               ^
#       ------------------------------------------------------------
#
#       scipy/special/_complexstuff.pxd:123:9: Assignment of Python object not allowed without gil
#       [332/1661] Generating 'scipy/special/_test_internal.cpython-313-x86_64-linux-gnu.so.p/_test_internal.c'
#       [333/1661] Generating scipy/linalg/interpolative_module with a custom command
#       [334/1661] Generating 'scipy/linalg/_solve_toeplitz.cpython-313-x86_64-linux-gnu.so.p/_solve_toeplitz.c'
#       [335/1661] Generating 'scipy/linalg/_matfuncs_sqrtm_triu.cpython-313-x86_64-linux-gnu.so.p/_matfuncs_sqrtm_triu.c'
#       [336/1661] Generating 'scipy/special/_ufuncs.cpython-313-x86_64-linux-gnu.so.p/_ufuncs.c'
#       FAILED: [code=1] scipy/special/_ufuncs.cpython-313-x86_64-linux-gnu.so.p/_ufuncs.c
#       /tmp/pip-build-env-z4tszrkn/overlay/bin/cython -3 --fast-fail --output-file scipy/special/_ufuncs.cpython-313-x86_64-linux-gnu.so.p/_ufuncs.c --include-dir . scipy/special/_ufuncs.pyx
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#
#       cdef inline number_t zpow(number_t x, double y) noexcept nogil:
#           cdef np.npy_cdouble r, z
#           # FIXME
#           if number_t is double_complex:
#               z.real = y
#               ^
#       ------------------------------------------------------------
#
#       scipy/special/_complexstuff.pxd:123:9: Assignment of Python object not allowed without gil
#       [337/1661] Generating 'scipy/linalg/cython_blas.cpython-313-x86_64-linux-gnu.so.p/cython_blas.c'
#       [338/1661] Generating 'scipy/linalg/_decomp_lu_cython.cpython-313-x86_64-linux-gnu.so.p/_decomp_lu_cython.c'
#       [339/1661] Generating 'scipy/linalg/_decomp_update.cpython-313-x86_64-linux-gnu.so.p/_decomp_update.c'
#       FAILED: [code=1] scipy/linalg/_decomp_update.cpython-313-x86_64-linux-gnu.so.p/_decomp_update.c
#       /tmp/pip-build-env-z4tszrkn/overlay/bin/cython -3 --fast-fail --output-file scipy/linalg/_decomp_update.cpython-313-x86_64-linux-gnu.so.p/_decomp_update.c --include-dir . scipy/linalg/_decomp_update.pyx
#
#       Error compiling Cython file:
#       ------------------------------------------------------------
#       ...
#           cdef void* uvoid
#           cdef int qs[2]
#           cdef int us[2]
#           cdef int ldu, p
#
#           if cnp.PyArray_CHKFLAGS(q, cnp.NPY_F_CONTIGUOUS):
#                                        ^
#       ------------------------------------------------------------
#
#       scipy/linalg/_decomp_update.pyx:1251:34: cimported module has no attribute 'NPY_F_CONTIGUOUS'
#       [340/1661] Generating 'scipy/linalg/_matfuncs_expm.cpython-313-x86_64-linux-gnu.so.p/_matfuncs_expm.c'
#       [341/1661] Generating 'scipy/linalg/_cythonized_array_utils.cpython-313-x86_64-linux-gnu.so.p/_cythonized_array_utils.c'
#       [342/1661] Generating 'scipy/linalg/cython_lapack.cpython-313-x86_64-linux-gnu.so.p/cython_lapack.c'
#       [343/1661] Generating scipy/linalg/flapack_module with a custom command
#       [344/1661] Compiling Fortran object scipy/special/libspecfun.a.p/specfun_specfun.f.o
#       ninja: build stopped: subcommand failed.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> scipy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import numpy as np
import sklearn
import shap

print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("SHAP:", shap.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import sklearn
# ----> 3 import shap
#       5 print("NumPy:", np.__version__)
#       6 print("Scikit-learn:", sklearn.__version__)
#
# ModuleNotFoundError: No module named 'shap'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

import shap
from lime.lime_tabular import LimeTabularExplainer
