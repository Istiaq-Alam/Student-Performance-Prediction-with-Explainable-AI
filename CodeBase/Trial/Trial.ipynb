# %%
# !pip install -q --upgrade --force-reinstall \
numpy==1.26.4 \
scipy==1.11.4 \
scikit-learn==1.4.2 \
pandas==2.1.4 \
matplotlib==3.8.4 \
seaborn==0.13.2 \
shap==0.44.1 \
lime==0.2.0.1 \
xgboost==2.0.3
# Out:
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [53 lines of output]
#       + meson setup /tmp/pip-install-xhh31dji/scipy_d48f3f344a374757bfa903eec64d3cfe /tmp/pip-install-xhh31dji/scipy_d48f3f344a374757bfa903eec64d3cfe/.mesonpy-rzovrv9u -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=/tmp/pip-install-xhh31dji/scipy_d48f3f344a374757bfa903eec64d3cfe/.mesonpy-rzovrv9u/meson-python-native-file.ini
#       The Meson build system
#       Version: 1.10.1
#       Source dir: /tmp/pip-install-xhh31dji/scipy_d48f3f344a374757bfa903eec64d3cfe
#       Build dir: /tmp/pip-install-xhh31dji/scipy_d48f3f344a374757bfa903eec64d3cfe/.mesonpy-rzovrv9u
#       Build type: native build
#       Project name: SciPy
#       Project version: 1.11.4
#       C compiler for the host machine: cc (gcc 15.2.0 "cc (Debian 15.2.0-12) 15.2.0")
#       C linker for the host machine: cc ld.bfd 2.45.50.20251209
#       C++ compiler for the host machine: c++ (gcc 15.2.0 "c++ (Debian 15.2.0-12) 15.2.0")
#       C++ linker for the host machine: c++ ld.bfd 2.45.50.20251209
#       Cython compiler for the host machine: cython (cython 0.29.37)
#       Host machine cpu family: x86_64
#       Host machine cpu: x86_64
#       Program python found: YES (/media/spyder/Secondary-Disk/Github/Student-Performance-Prediction-with-Explainable-AI/CodeBase/Trial/.spenv/bin/python3)
#       Found pkg-config: YES (/usr/bin/pkg-config) 1.8.1
#       Run-time dependency python found: YES 3.13
#       Program cython found: YES (/tmp/pip-build-env-hxg6v7h1/overlay/bin/cython)
#       Compiler for C supports arguments -Wno-unused-but-set-variable: YES
#       Compiler for C supports arguments -Wno-unused-function: YES
#       Compiler for C supports arguments -Wno-conversion: YES
#       Compiler for C supports arguments -Wno-misleading-indentation: YES
#       Library m found: YES
#
#       ../meson.build:80:0: ERROR: Unknown compiler(s): [['gfortran'], ['flang-new'], ['flang'], ['nvfortran'], ['pgfortran'], ['ifort'], ['ifx'], ['g95']]
#       The following exception(s) were encountered:
#       Running `gfortran --help` gave "[Errno 2] No such file or directory: 'gfortran'"
#       Running `gfortran --version` gave "[Errno 2] No such file or directory: 'gfortran'"
#       Running `gfortran -V` gave "[Errno 2] No such file or directory: 'gfortran'"
#       Running `flang-new --help` gave "[Errno 2] No such file or directory: 'flang-new'"
#       Running `flang-new --version` gave "[Errno 2] No such file or directory: 'flang-new'"
#       Running `flang-new -V` gave "[Errno 2] No such file or directory: 'flang-new'"
#       Running `flang --help` gave "[Errno 2] No such file or directory: 'flang'"
#       Running `flang --version` gave "[Errno 2] No such file or directory: 'flang'"
#       Running `flang -V` gave "[Errno 2] No such file or directory: 'flang'"
#       Running `nvfortran --help` gave "[Errno 2] No such file or directory: 'nvfortran'"
#       Running `nvfortran --version` gave "[Errno 2] No such file or directory: 'nvfortran'"
#       Running `nvfortran -V` gave "[Errno 2] No such file or directory: 'nvfortran'"
#       Running `pgfortran --help` gave "[Errno 2] No such file or directory: 'pgfortran'"
#       Running `pgfortran --version` gave "[Errno 2] No such file or directory: 'pgfortran'"
#       Running `pgfortran -V` gave "[Errno 2] No such file or directory: 'pgfortran'"
#       Running `ifort --help` gave "[Errno 2] No such file or directory: 'ifort'"
#       Running `ifort --version` gave "[Errno 2] No such file or directory: 'ifort'"
#       Running `ifort -V` gave "[Errno 2] No such file or directory: 'ifort'"
#       Running `ifx --help` gave "[Errno 2] No such file or directory: 'ifx'"
#       Running `ifx --version` gave "[Errno 2] No such file or directory: 'ifx'"
#       Running `ifx -V` gave "[Errno 2] No such file or directory: 'ifx'"
#       Running `g95 --help` gave "[Errno 2] No such file or directory: 'g95'"
#       Running `g95 --version` gave "[Errno 2] No such file or directory: 'g95'"
#       Running `g95 -V` gave "[Errno 2] No such file or directory: 'g95'"
#
#       A full log can be found at /tmp/pip-install-xhh31dji/scipy_d48f3f344a374757bfa903eec64d3cfe/.mesonpy-rzovrv9u/meson-logs/meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'scipy' when getting requirements to build wheel

# %%
import numpy as np
import sklearn
import shap

print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("SHAP:", shap.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 import sklearn
# ----> 3 import shap
#       5 print("NumPy:", np.__version__)
#       6 print("Scikit-learn:", sklearn.__version__)
#
# ModuleNotFoundError: No module named 'shap'
